# %% [markdown]
# <a href="https://colab.research.google.com/github/moulisha10/tweetgenerating_agent/blob/main/simple_ai_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-generativeai --quiet
# !pip install ipywidgets --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 26.1 MB/s eta 0:00:00

# %%
os.environ['GOOGLE_API_KEY'] = getpass.getpass("Enter the Gemini API Key")

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

# %%
import google.generativeai as genai
import ipywidgets as widgets
from IPython.display import display, Markdown

# %%
topic_input=widgets.Text(
    description="Topic",
    layout=widgets.Layout(width="500px")
)
tone_input=widgets.Dropdown(
    description="Tone",
    options =['Professional','Casual','Motivational','Informative'],
    layout=widgets.Layout(width="500px")
)
audience_input=widgets.Text(
    description="Audience",
    layout=widgets.Layout(width="500px")
)
hashtag_input=widgets.Text(
    description="Hashtags",
    layout=widgets.Layout(width="500px")
)
submit_button=widgets.Button(
    description="Generate Tweet",
    button_style="Success",
    tooltip="Click to generate tweet",
    layout=widgets.Layout(width="500px")
)
output=widgets.Output()

# %%
def generate_tweet(b):
  output.clear_output()
  prompt = f"""
  generate a tweet about the topic "{topic_input.value}".
  use a tone {tone_input.value}.
  generate tweet for audience {audience_input.value}.
  use hashtags {hashtag_input.value}.
  keep it under 200 characters
  """
  with output:
    try:
      response = model.generate_content(prompt)
      tweet = response.text.strip()
      display(Markdown(f"###Generates Tweet:\n\n{tweet}"))
    except Exception as e:
      print("Error",e)
submit_button.on_click(generate_tweet)

# %%
form = widgets.VBox([
    widgets.HTML(value="<h1>Generate Tweet</h1>"),
    topic_input,
    tone_input,
    audience_input,
    hashtag_input,
    submit_button,
    output])
display(form)
# Out:
# ###Generates Tweet:
#
# Seeking your next cinematic experience? Let us know your preferred genre or mood for tailored #movie suggestions.
